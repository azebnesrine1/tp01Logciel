# %%
pip install numpy pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-2.3.5-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\roaming\python\python314\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading numpy-2.3.5-cp314-cp314-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.9 MB 1.1 MB/s eta 0:00:12
#    - -------------------------------------- 0.5/12.9 MB 1.1 MB/s eta 0:00:12
#    -- ------------------------------------- 0.8/12.9 MB 726.4 kB/s eta 0:00:17
#    -- ------------------------------------- 0.8/12.9 MB 726.4 kB/s eta 0:00:17
#    --- ------------------------------------ 1.0/12.9 MB 701.7 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.3/12.9 MB 758.0 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.6/12.9 MB 812.8 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.6/12.9 MB 812.8 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.8/12.9 MB 843.2 kB/s eta 0:00:14
#    ------ --------------------------------- 2.1/12.9 MB 893.9 kB/s eta 0:00:13
#    ------- -------------------------------- 2.4/12.9 MB 931.7 kB/s eta 0:00:12
#    -------- ------------------------------- 2.6/12.9 MB 956.9 kB/s eta 0:00:11
#    --------- ------------------------------ 3.1/12.9 MB 1.0 MB/s eta 0:00:10
#    --------- ------------------------------ 3.1/12.9 MB 1.0 MB/s eta 0:00:10
#    ---------- ----------------------------- 3.4/12.9 MB 1.0 MB/s eta 0:00:10
#    ----------- ---------------------------- 3.7/12.9 MB 1.0 MB/s eta 0:00:09
#    ------------ --------------------------- 3.9/12.9 MB 1.0 MB/s eta 0:00:09
#    ------------ --------------------------- 4.2/12.9 MB 1.0 MB/s eta 0:00:09
#    ------------- -------------------------- 4.5/12.9 MB 1.1 MB/s eta 0:00:08
#    ------------- -------------------------- 4.5/12.9 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 4.7/12.9 MB 1.0 MB/s eta 0:00:09
#    -------------- ------------------------- 4.7/12.9 MB 1.0 MB/s eta 0:00:09
#    --------------- ------------------------ 5.0/12.9 MB 1.0 MB/s eta 0:00:08
#    ---------------- ----------------------- 5.2/12.9 MB 1.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 5.5/12.9 MB 999.7 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.5/12.9 MB 999.7 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.5/12.9 MB 999.7 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.8/12.9 MB 954.8 kB/s eta 0:00:08
#    ------------------ --------------------- 6.0/12.9 MB 944.8 kB/s eta 0:00:08
#    ------------------- -------------------- 6.3/12.9 MB 956.7 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/12.9 MB 971.5 kB/s eta 0:00:07
#    --------------------- ------------------ 6.8/12.9 MB 984.8 kB/s eta 0:00:07
#    --------------------- ------------------ 7.1/12.9 MB 992.7 kB/s eta 0:00:06
#    ---------------------- ----------------- 7.3/12.9 MB 1.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 7.3/12.9 MB 1.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.6/12.9 MB 984.6 kB/s eta 0:00:06
#    ------------------------ --------------- 7.9/12.9 MB 981.8 kB/s eta 0:00:06
#    ------------------------- -------------- 8.1/12.9 MB 990.0 kB/s eta 0:00:05
#    ------------------------- -------------- 8.4/12.9 MB 998.0 kB/s eta 0:00:05
#    ------------------------- -------------- 8.4/12.9 MB 998.0 kB/s eta 0:00:05
#    ------------------------- -------------- 8.4/12.9 MB 998.0 kB/s eta 0:00:05
#    -------------------------- ------------- 8.7/12.9 MB 970.5 kB/s eta 0:00:05
#    -------------------------- ------------- 8.7/12.9 MB 970.5 kB/s eta 0:00:05
#    --------------------------- ------------ 8.9/12.9 MB 950.1 kB/s eta 0:00:05
#    --------------------------- ------------ 8.9/12.9 MB 950.1 kB/s eta 0:00:05
#    ---------------------------- ----------- 9.2/12.9 MB 948.6 kB/s eta 0:00:04
#    ---------------------------- ----------- 9.2/12.9 MB 948.6 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.4/12.9 MB 921.2 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.4/12.9 MB 921.2 kB/s eta 0:00:04
#    ------------------------------ --------- 9.7/12.9 MB 915.5 kB/s eta 0:00:04
#    ------------------------------ --------- 9.7/12.9 MB 915.5 kB/s eta 0:00:04
#    ------------------------------ --------- 10.0/12.9 MB 914.6 kB/s eta 0:00:04
#    ---------------------------------------- 12.9/12.9 MB 866.1 kB/s  0:00:15
# Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.1 MB 68.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.3/11.1 MB 3.8 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/11.1 MB 3.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.1 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.1 MB 1.7 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/11.1 MB 1.5 MB/s eta 0:00:07
#    ------- -------------------------------- 2.1/11.1 MB 1.4 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/11.1 MB 1.4 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/11.1 MB 1.4 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/11.1 MB 1.2 MB/s eta 0:00:08
#    --------- ------------------------------ 2.6/11.1 MB 1.2 MB/s eta 0:00:08
#    ---------- ----------------------------- 2.9/11.1 MB 1.1 MB/s eta 0:00:08
#    ------------ --------------------------- 3.4/11.1 MB 1.2 MB/s eta 0:00:07
#    ------------- -------------------------- 3.7/11.1 MB 1.2 MB/s eta 0:00:07
#    --------------- ------------------------ 4.2/11.1 MB 1.3 MB/s eta 0:00:06
#    --------------- ------------------------ 4.2/11.1 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.5/11.1 MB 1.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.7/11.1 MB 1.2 MB/s eta 0:00:06
#    ------------------ --------------------- 5.2/11.1 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 5.8/11.1 MB 1.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.3/11.1 MB 1.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.3/11.1 MB 1.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.6/11.1 MB 1.4 MB/s eta 0:00:04
#    ------------------------ --------------- 6.8/11.1 MB 1.4 MB/s eta 0:00:04
#    -------------------------- ------------- 7.3/11.1 MB 1.4 MB/s eta 0:00:03
#    --------------------------- ------------ 7.6/11.1 MB 1.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.1/11.1 MB 1.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.1/11.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------------- -------- 8.7/11.1 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.1 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 9.4/11.1 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.4/11.1 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.7/11.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.1 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 1.4 MB/s  0:00:09
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, numpy, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed numpy-2.3.5 pandas-2.3.3 pytz-2025.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\DELL\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sample         20 non-null     object
#  1   group          20 non-null     object
#  2   cell_count     20 non-null     int64
#  3   protein_level  20 non-null     float64
#  4   growth_rate    20 non-null     float64
#  5   temperature    20 non-null     int64
#  6   ph             20 non-null     float64
#  7   oxygen         20 non-null     float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#        cell_count  protein_level  growth_rate  temperature         ph  \
# count   20.000000      20.000000    20.000000    20.000000  20.000000
# mean   156.650000       3.040000     0.960000    28.500000   7.290000
# std     28.062477       0.615074     0.150997     5.642881   0.116529
# min    110.000000       2.100000     0.750000    20.000000   7.100000
# 25%    138.750000       2.575000     0.837500    25.000000   7.200000
# 50%    152.500000       2.900000     0.915000    30.000000   7.300000
# 75%    181.250000       3.625000     1.105000    35.000000   7.400000
# max    200.000000       4.000000     1.200000    35.000000   7.500000
#
#           oxygen
# count  20.000000
# mean    7.540000
# std     0.342437
# min     7.000000
# 25%     7.275000
# 50%     7.500000
# 75%     7.825000
# max     8.100000

# %%
import pandas as pd

df = pd.read_csv("data_biology.csv")
df
# Out:
#    sample    group  cell_count  protein_level  growth_rate  temperature   ph  \
# 0     S01  Control         110            2.1         0.75           20  7.2
# 1     S02  Control         115            2.2         0.78           20  7.1
# 2     S03  Control         120            2.4         0.80           25  7.2
# 3     S04  Control         130            2.5         0.82           25  7.3
# 4     S05  Control         140            2.6         0.85           30  7.4
# 5     S06  Control         145            2.7         0.87           30  7.3
# 6     S07  Control         150            2.8         0.88           35  7.5
# 7     S08  Control         148            2.7         0.86           35  7.4
# 8     S09  Control         142            2.6         0.84           35  7.3
# 9     S10  Control         135            2.5         0.83           30  7.2
# 10    S11  Treated         155            3.0         0.95           20  7.2
# 11    S12  Treated         160            3.1         0.98           20  7.1
# 12    S13  Treated         165            3.3         1.02           25  7.2
# 13    S14  Treated         170            3.4         1.05           25  7.3
# 14    S15  Treated         180            3.6         1.10           30  7.4
# 15    S16  Treated         185            3.7         1.12           30  7.3
# 16    S17  Treated         190            3.8         1.15           35  7.5
# 17    S18  Treated         195            3.9         1.18           35  7.4
# 18    S19  Treated         200            4.0         1.20           35  7.3
# 19    S20  Treated         198            3.9         1.17           30  7.2
#
#     oxygen
# 0      8.1
# 1      8.0
# 2      7.9
# 3      7.8
# 4      7.6
# 5      7.5
# 6      7.3
# 7      7.2
# 8      7.1
# 9      7.4
# 10     8.0
# 11     7.9
# 12     7.8
# 13     7.7
# 14     7.5
# 15     7.4
# 16     7.2
# 17     7.1
# 18     7.0
# 19     7.3

# %%
df[["cell_count", "protein_level"]]
# Out:
#     cell_count  protein_level
# 0          110            2.1
# 1          115            2.2
# 2          120            2.4
# 3          130            2.5
# 4          140            2.6
# 5          145            2.7
# 6          150            2.8
# 7          148            2.7
# 8          142            2.6
# 9          135            2.5
# 10         155            3.0
# 11         160            3.1
# 12         165            3.3
# 13         170            3.4
# 14         180            3.6
# 15         185            3.7
# 16         190            3.8
# 17         195            3.9
# 18         200            4.0
# 19         198            3.9

# %%
treated = df[df["group"] == "Treated"]
treated
# Out:
#    sample    group  cell_count  protein_level  growth_rate  temperature   ph  \
# 10    S11  Treated         155            3.0         0.95           20  7.2
# 11    S12  Treated         160            3.1         0.98           20  7.1
# 12    S13  Treated         165            3.3         1.02           25  7.2
# 13    S14  Treated         170            3.4         1.05           25  7.3
# 14    S15  Treated         180            3.6         1.10           30  7.4
# 15    S16  Treated         185            3.7         1.12           30  7.3
# 16    S17  Treated         190            3.8         1.15           35  7.5
# 17    S18  Treated         195            3.9         1.18           35  7.4
# 18    S19  Treated         200            4.0         1.20           35  7.3
# 19    S20  Treated         198            3.9         1.17           30  7.2
#
#     oxygen
# 10     8.0
# 11     7.9
# 12     7.8
# 13     7.7
# 14     7.5
# 15     7.4
# 16     7.2
# 17     7.1
# 18     7.0
# 19     7.3

# %%
import numpy as np
np.mean(df["cell_count"])
# Out:
# np.float64(156.65)

# %%
np.std(df["cell_count"])
# Out:
# np.float64(27.351919493885617)

# %%
df.groupby("group")["cell_count"].mean()
# Out:
# group
# Control    133.5
# Treated    179.8
# Name: cell_count, dtype: float64

# %%
df["normalized_growth"] = df["growth_rate"] / df["growth_rate"].max()
df
# Out:
#    sample    group  cell_count  protein_level  growth_rate  temperature   ph  \
# 0     S01  Control         110            2.1         0.75           20  7.2
# 1     S02  Control         115            2.2         0.78           20  7.1
# 2     S03  Control         120            2.4         0.80           25  7.2
# 3     S04  Control         130            2.5         0.82           25  7.3
# 4     S05  Control         140            2.6         0.85           30  7.4
# 5     S06  Control         145            2.7         0.87           30  7.3
# 6     S07  Control         150            2.8         0.88           35  7.5
# 7     S08  Control         148            2.7         0.86           35  7.4
# 8     S09  Control         142            2.6         0.84           35  7.3
# 9     S10  Control         135            2.5         0.83           30  7.2
# 10    S11  Treated         155            3.0         0.95           20  7.2
# 11    S12  Treated         160            3.1         0.98           20  7.1
# 12    S13  Treated         165            3.3         1.02           25  7.2
# 13    S14  Treated         170            3.4         1.05           25  7.3
# 14    S15  Treated         180            3.6         1.10           30  7.4
# 15    S16  Treated         185            3.7         1.12           30  7.3
# 16    S17  Treated         190            3.8         1.15           35  7.5
# 17    S18  Treated         195            3.9         1.18           35  7.4
# 18    S19  Treated         200            4.0         1.20           35  7.3
# 19    S20  Treated         198            3.9         1.17           30  7.2
#
#     oxygen  normalized_growth
# 0      8.1           0.625000
# 1      8.0           0.650000
# 2      7.9           0.666667
# 3      7.8           0.683333
# 4      7.6           0.708333
# 5      7.5           0.725000
# 6      7.3           0.733333
# 7      7.2           0.716667
# 8      7.1           0.700000
# 9      7.4           0.691667
# 10     8.0           0.791667
# 11     7.9           0.816667
# 12     7.8           0.850000
# 13     7.7           0.875000
# 14     7.5           0.916667
# 15     7.4           0.933333
# 16     7.2           0.958333
# 17     7.1           0.983333
# 18     7.0           1.000000
# 19     7.3           0.975000

# %%
high_protein = np.where(df["protein_level"] > 3.0, "High", "Normal")
df["protein_status"] = high_protein
df
# Out:
#    sample    group  cell_count  protein_level  growth_rate  temperature   ph  \
# 0     S01  Control         110            2.1         0.75           20  7.2
# 1     S02  Control         115            2.2         0.78           20  7.1
# 2     S03  Control         120            2.4         0.80           25  7.2
# 3     S04  Control         130            2.5         0.82           25  7.3
# 4     S05  Control         140            2.6         0.85           30  7.4
# 5     S06  Control         145            2.7         0.87           30  7.3
# 6     S07  Control         150            2.8         0.88           35  7.5
# 7     S08  Control         148            2.7         0.86           35  7.4
# 8     S09  Control         142            2.6         0.84           35  7.3
# 9     S10  Control         135            2.5         0.83           30  7.2
# 10    S11  Treated         155            3.0         0.95           20  7.2
# 11    S12  Treated         160            3.1         0.98           20  7.1
# 12    S13  Treated         165            3.3         1.02           25  7.2
# 13    S14  Treated         170            3.4         1.05           25  7.3
# 14    S15  Treated         180            3.6         1.10           30  7.4
# 15    S16  Treated         185            3.7         1.12           30  7.3
# 16    S17  Treated         190            3.8         1.15           35  7.5
# 17    S18  Treated         195            3.9         1.18           35  7.4
# 18    S19  Treated         200            4.0         1.20           35  7.3
# 19    S20  Treated         198            3.9         1.17           30  7.2
#
#     oxygen  normalized_growth protein_status
# 0      8.1           0.625000         Normal
# 1      8.0           0.650000         Normal
# 2      7.9           0.666667         Normal
# 3      7.8           0.683333         Normal
# 4      7.6           0.708333         Normal
# 5      7.5           0.725000         Normal
# 6      7.3           0.733333         Normal
# 7      7.2           0.716667         Normal
# 8      7.1           0.700000         Normal
# 9      7.4           0.691667         Normal
# 10     8.0           0.791667         Normal
# 11     7.9           0.816667           High
# 12     7.8           0.850000           High
# 13     7.7           0.875000           High
# 14     7.5           0.916667           High
# 15     7.4           0.933333           High
# 16     7.2           0.958333           High
# 17     7.1           0.983333           High
# 18     7.0           1.000000           High
# 19     7.3           0.975000           High

# %%
import matplotlib.pyplot as plt
df.plot(kind="bar", x="sample", y="cell_count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 df.plot(kind="bar", x="sample", y="cell_count")
#       3 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df.boxplot(column="cell_count", by="group")
plt.title("Cell count by group")
plt.suptitle("")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.boxplot(column="cell_count", by="group")
#       2 plt.title("Cell count by group")
#       3 plt.suptitle("")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\plotting\_core.py:532, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)    530     **kwargs,
#     531 ):
# --> 532     plot_backend = _get_plot_backend(backend)
#     533     return plot_backend.boxplot_frame(
#     534         self,
#     535         column=column,
#    (...)    544         **kwargs,
#     545     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\plotting\_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\plotting\_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
df.plot(kind="scatter", x="temperature", y="growth_rate")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.plot(kind="scatter", x="temperature", y="growth_rate")
#       2 plt.show()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\plotting\_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# --> 947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     949     x, y, kind, kwargs = self._get_call_args(
#     950         plot_backend.__name__, self._parent, args, kwargs
#     951     )
#     953     kind = self._kind_aliases.get(kind, kind)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\plotting\_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\plotting\_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
data_np = df[["cell_count", "protein_level", "growth_rate"]].to_numpy()
data_np
# Out:
# array([[110.  ,   2.1 ,   0.75],
#        [115.  ,   2.2 ,   0.78],
#        [120.  ,   2.4 ,   0.8 ],
#        [130.  ,   2.5 ,   0.82],
#        [140.  ,   2.6 ,   0.85],
#        [145.  ,   2.7 ,   0.87],
#        [150.  ,   2.8 ,   0.88],
#        [148.  ,   2.7 ,   0.86],
#        [142.  ,   2.6 ,   0.84],
#        [135.  ,   2.5 ,   0.83],
#        [155.  ,   3.  ,   0.95],
#        [160.  ,   3.1 ,   0.98],
#        [165.  ,   3.3 ,   1.02],
#        [170.  ,   3.4 ,   1.05],
#        [180.  ,   3.6 ,   1.1 ],
#        [185.  ,   3.7 ,   1.12],
#        [190.  ,   3.8 ,   1.15],
#        [195.  ,   3.9 ,   1.18],
#        [200.  ,   4.  ,   1.2 ],
#        [198.  ,   3.9 ,   1.17]])

# %%
df[["cell_count", "protein_level", "growth_rate"]].corr()
# Out:
#                cell_count  protein_level  growth_rate
# cell_count       1.000000       0.991555     0.983611
# protein_level    0.991555       1.000000     0.997389
# growth_rate      0.983611       0.997389     1.000000

# %%
df.to_csv("results_biology.csv", index=False)
